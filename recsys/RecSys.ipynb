# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import scipy as sp
import matplotlib.pyplot as plt

# %%
run eda

# %%
ll = bus_data.loc[review_data.loc[:,'business_id'],['latitude','longitude']]
plt.scatter(ll.latitude, ll.longitude, c=review_data.stars, marker='.')
plt.gray()

# %%
# Out:
# Index([u'categories', u'city', u'full_address', u'latitude', u'longitude', u'name', u'open', u'review_count', u'stars', u'state'], dtype=object)
